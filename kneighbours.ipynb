# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_csv("heart_cleveland_upload.csv")

# %%
X = df.drop('condition', axis=1)
y = df['condition']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 90.00%

# %%
age=int(input('age'))
sex=int(input('1 male and 0 female'))
cp=int(input('chect pain level 0 to 3 '))
trestbps=int(input('bps 94 to 200'))
chol=int(input('chol 126 to 254'))
fbs=int(input('fbs 0 less then 120 and more then 120'))
restecg=int(input('ecg values 0,1,3'))
thalac=int(input('thalc 71 to 202'))
exang=int(input('exang 0 no chest pain b exer and 1 yes '))
oldpeak=float(input('oldpeak 0.0 to 6.2'))
slope=int(input('slope 0 1 2'))
ca=int(input('vessel blocakge 0 to 3'))
thal= int(input('thalasemia 0 to 3'))
# Format: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal]
new_patient = [[age, sex, cp, trestbps, chol, fbs, restecg, thalac, exang, oldpeak, slope, ca, thal]]  
new_patient_scaled = scaler.transform(new_patient)
prediction = knn.predict(new_patient_scaled)

if prediction[0] == 1:
    print("Prediction: Patient has heart disease (Condition = 1)")
else:
    print("Prediction: Patient does NOT have heart disease (Condition = 0)")
# Out:
# age 30
# 1 male and 0 female 0
# chect pain level 0 to 3  0
# bps 94 to 200 120
# chol 126 to 254 140
# fbs 0 less then 120 and more then 120 0
# ecg values 0,1,3 2
# thalc 71 to 202 100
# exang 0 no chest pain b exer and 1 yes  0
# oldpeak 0.0 to 6.2 3.2
# slope 0 1 2 0
# vessel blocakge 0 to 3 0
# thalasemia 0 to 3 1
# Prediction: Patient does NOT have heart disease (Condition = 0)
# D:\python\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     69    1   0       160   234    1        2      131      0      0.1
# 1     69    0   0       140   239    0        0      151      0      1.8
# 2     66    0   0       150   226    0        0      114      0      2.6
# 3     65    1   0       138   282    1        2      174      0      1.4
# 4     64    1   0       110   211    0        2      144      1      1.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 292   40    1   3       152   223    0        0      181      0      0.0
# 293   39    1   3       118   219    0        0      140      0      1.2
# 294   35    1   3       120   198    0        0      130      1      1.6
# 295   35    0   3       138   183    0        0      182      0      1.4
# 296   35    1   3       126   282    0        2      156      1      0.0
#
#      slope  ca  thal  condition
# 0        1   1     0          0
# ...
