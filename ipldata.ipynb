# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import streamlit as slt

# %%
deliveries=pd.read_csv("deliveriesipl.csv")
matches=pd.read_csv("matchesipl.csv")

# %%
s_2007_08=matches[matches["season"]=="2007/08"]
s_2009=matches[matches["season"]=="2009"]
s_2009_10=matches[matches["season"]=="2009/10"]
s_2011=matches[matches["season"]=="2011"]
s_2012=matches[matches["season"]=="2012"]
s_2013=matches[matches["season"]=="2013"]
s_2014=matches[matches["season"]=="2014"]
s_2015=matches[matches["season"]=="2015"]
s_2016=matches[matches["season"]=="2016"]
s_2017=matches[matches["season"]=="2017"]
s_2018=matches[matches["season"]=="2018"]
s_2019=matches[matches["season"]=="2019"]
s_2020_21=matches[matches["season"]=="2020/21"]
s_2021=matches[matches["season"]=="2021"]
s_2022=matches[matches["season"]=="2022"]
s_2023=matches[matches["season"]=="2023"]
s_2024=matches[matches["season"]=="2024"]

# %%
alldata=pd.merge(matches, deliveries, left_on="id", right_on="match_id", how="inner")

# %%
s1_07_08=pd.merge(s_2007_08, deliveries, left_on="id", right_on="match_id", how="inner")
s2_09=pd.merge(s_2009, deliveries, left_on="id", right_on="match_id", how="inner")
s3_09_10=pd.merge(s_2009_10, deliveries, left_on="id", right_on="match_id", how="inner")
s4_11=pd.merge(s_2011, deliveries, left_on="id", right_on="match_id", how="inner")
s5_12=pd.merge(s_2012, deliveries, left_on="id", right_on="match_id", how="inner")
s6_13=pd.merge(s_2013, deliveries, left_on="id", right_on="match_id", how="inner")
s7_14=pd.merge(s_2014, deliveries, left_on="id", right_on="match_id", how="inner")
s8_15=pd.merge(s_2015, deliveries, left_on="id", right_on="match_id", how="inner")
s9_16=pd.merge(s_2016, deliveries, left_on="id", right_on="match_id", how="inner")
s10_17=pd.merge(s_2017, deliveries, left_on="id", right_on="match_id", how="inner")
s11_18=pd.merge(s_2018, deliveries, left_on="id", right_on="match_id", how="inner")
s12_19=pd.merge(s_2019, deliveries, left_on="id", right_on="match_id", how="inner")
s13_20_21=pd.merge(s_2020_21, deliveries, left_on="id", right_on="match_id", how="inner")
s14_21=pd.merge(s_2021, deliveries, left_on="id", right_on="match_id", how="inner")
s15_22=pd.merge(s_2022, deliveries, left_on="id", right_on="match_id", how="inner")
s16_23=pd.merge(s_2023, deliveries, left_on="id", right_on="match_id", how="inner")
s17_24=pd.merge(s_2024, deliveries, left_on="id", right_on="match_id", how="inner")

# %%
match1_s1=s1_07_08[s1_07_08["id"]==335982]
match2_s1=s1_07_08[s1_07_08["id"]==335983]
match3_s1=s1_07_08[s1_07_08["id"]==335984]
match4_s1=s1_07_08[s1_07_08["id"]==335985]
match5_s1=s1_07_08[s1_07_08["id"]==335986]
match6_s1=s1_07_08[s1_07_08["id"]==335987]
match7_s1=s1_07_08[s1_07_08["id"]==335988]
match8_s1=s1_07_08[s1_07_08["id"]==335989]
match9_s1=s1_07_08[s1_07_08["id"]==335990]
match10_s1=s1_07_08[s1_07_08["id"]==335991]
match11_s1=s1_07_08[s1_07_08["id"]==335992]
match12_s1=s1_07_08[s1_07_08["id"]==335993]
match13_s1=s1_07_08[s1_07_08["id"]==335994]
match14_s1=s1_07_08[s1_07_08["id"]==335995]
match15_s1=s1_07_08[s1_07_08["id"]==335996]
match16_s1=s1_07_08[s1_07_08["id"]==335997]
match17_s1=s1_07_08[s1_07_08["id"]==335998]
match18_s1=s1_07_08[s1_07_08["id"]==335999]
match19_s1=s1_07_08[s1_07_08["id"]==336000]
match20_s1=s1_07_08[s1_07_08["id"]==336001]
match21_s1=s1_07_08[s1_07_08["id"]==336002]
match22_s1=s1_07_08[s1_07_08["id"]==336003]
match23_s1=s1_07_08[s1_07_08["id"]==336004]
match24_s1=s1_07_08[s1_07_08["id"]==336005]
match25_s1=s1_07_08[s1_07_08["id"]==336006]
match26_s1=s1_07_08[s1_07_08["id"]==336007]
match27_s1=s1_07_08[s1_07_08["id"]==336008]
match28_s1=s1_07_08[s1_07_08["id"]==336009]
match29_s1=s1_07_08[s1_07_08["id"]==336010]
match30_s1=s1_07_08[s1_07_08["id"]==336011]
match31_s1=s1_07_08[s1_07_08["id"]==336012]
match32_s1=s1_07_08[s1_07_08["id"]==336013]
match33_s1=s1_07_08[s1_07_08["id"]==336014]
match34_s1=s1_07_08[s1_07_08["id"]==336015]
match35_s1=s1_07_08[s1_07_08["id"]==336016]
match36_s1=s1_07_08[s1_07_08["id"]==336017]
match37_s1=s1_07_08[s1_07_08["id"]==336018]
match38_s1=s1_07_08[s1_07_08["id"]==336019]
match39_s1=s1_07_08[s1_07_08["id"]==336020]
match40_s1=s1_07_08[s1_07_08["id"]==336021]
match41_s1=s1_07_08[s1_07_08["id"]==336022]
match42_s1=s1_07_08[s1_07_08["id"]==336023]
match43_s1=s1_07_08[s1_07_08["id"]==336024]
match44_s1=s1_07_08[s1_07_08["id"]==336025]
match45_s1=s1_07_08[s1_07_08["id"]==336026]
match46_s1=s1_07_08[s1_07_08["id"]==336027]
match47_s1=s1_07_08[s1_07_08["id"]==336028]
match48_s1=s1_07_08[s1_07_08["id"]==336029]
match49_s1=s1_07_08[s1_07_08["id"]==336030]
match50_s1=s1_07_08[s1_07_08["id"]==336031]
match51_s1=s1_07_08[s1_07_08["id"]==336032]
match52_s1=s1_07_08[s1_07_08["id"]==336033]
match53_s1=s1_07_08[s1_07_08["id"]==336034]
match54_s1=s1_07_08[s1_07_08["id"]==336035]
match55_s1=s1_07_08[s1_07_08["id"]==336036]
match56_s1=s1_07_08[s1_07_08["id"]==336037]
match57_s1=s1_07_08[s1_07_08["id"]==336038]
match58_s1=s1_07_08[s1_07_08["id"]==336039]
match59_s1=s1_07_08[s1_07_08["id"]==336040]

# %%
for i in range(57):
    globals()["match"+str(i)+"_s2"] = s2_09[s2_09["id"]==392180+i].reset_index()

# %%
for i in range(60):
    globals()["match"+str(i)+"_s3"] = s3_09_10[s3_09_10["id"]==419105+i].reset_index()

# %%
for i in range(73):
    globals()["match"+str(i)+"_s4"] = s4_11[s4_11["id"]==501197+i].reset_index()

# %%
for i in range(74):
    globals()["match"+str(i)+"_s5"] = s4_11[s4_11["id"]==548306+i].reset_index()

# %%
for i in range(76):
    globals()["match"+str(i)+"_s6"] = s5_12[s5_12["id"]==597998+i].reset_index()

# %%
for i in range(60):
    globals()["match"+str(i)+"_s7"] = s7_14[s7_14["id"]==729277+2*i].reset_index()

# %%
for i in range(59):
    globals()["match"+str(i)+"_s8"] = s8_15[s8_15["id"]==829703+2*i].reset_index()

# %%
for i in range(60):
    globals()["match"+str(i)+"_s9"] = s9_16[s9_16["id"]==980899+2*i].reset_index()

# %%
for i in range(59):
    globals()["match"+str(i)+"_s10"] = s10_17[s10_17["id"]==1082590+i].reset_index()

# %%
for i in range(60):
    globals()["match"+str(i)+"_s11"] = s11_18[s11_18["id"]==1136560+i].reset_index()

# %%
for i in range(60):
    globals()["match"+str(i)+"_s12"] = s12_19[s12_19["id"]==1175355+i].reset_index()

# %%
for i in range(60):
    globals()["match"+str(i)+"_s13"] = s13_20_21[s13_20_21["id"]==1216491+i].reset_index()

# %%
for i in range(60):
    globals()["match"+str(i)+"_s14"] = s14_21[s14_21["id"]==1254057+i].reset_index()

# %%
for i in range(74):
    globals()["match"+str(i)+"_s15"] = s15_22[s15_22["id"]==1304046+i].reset_index()

# %%
for i in range(74):
    globals()["match"+str(i)+"_s16"] = s16_23[s16_23["id"]==1359474+i].reset_index()

# %%
for i in range(71):
    globals()["match"+str(i)+"_s17"] = s17_24[s17_24["id"]==1422118+i].reset_index()

# %%
def over(a,b,c):
    aa=a[(a["over"] == b) & (a["inning"] == c)].reset_index()
    columns_to_drop = ['id', 'season', 'venue', 'toss_decision','winner','result','result_margin', 'match_id', 'index', 'city', 'match_type', 'player_of_match', 'toss_winner', 'target_runs', 'target_overs', 'team1', 'team2', 'super_over', 'method', 'umpire1', 'umpire2']
    aa = aa.drop(columns=columns_to_drop)
    return aa

# %%
def create_over_variables(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s1"] = over(match, i, innings)

# %%
def create_over_variables2(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s2"] = over(match, i, innings)

# %%
def create_over_variables3(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s3"] = over(match, i, innings)

# %%
def create_over_variables4(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s4"] = over(match, i, innings)

# %%
def create_over_variables5(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s5"] = over(match, i, innings)

# %%
def create_over_variables6(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s6"] = over(match, i, innings)

# %%
def create_over_variables7(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s7"] = over(match, i, innings)

# %%
def create_over_variables8(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s8"] = over(match, i, innings)

# %%
def create_over_variables9(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s9"] = over(match, i, innings)

# %%
def create_over_variables10(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s10"] = over(match, i, innings)

# %%
def create_over_variables11(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s11"] = over(match, i, innings)

# %%
def create_over_variables12(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s12"] = over(match, i, innings)

# %%
def create_over_variables13(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s13"] = over(match, i, innings)

# %%
def create_over_variables14(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s14"] = over(match, i, innings)

# %%
def create_over_variables15(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s15"] = over(match, i, innings)

# %%
def create_over_variables16(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s16"] = over(match, i, innings)

# %%
def create_over_variables17(match, num_iterations, innings, match_id):
    for i in range(num_iterations):
        globals()[f"over{i}i{innings}_{match_id}_s17"] = over(match, i, innings)

# %%
create_over_variables(match1_s1, 20, 1, 'm1')
create_over_variables(match1_s1, 20, 2, 'm1')

# %%
def create_variable_values_list(prefix='match', start=1, end=60, suffix='s17'):
    variable_values = []
    for i in range(start, end + 1):
        variable_name = f'{prefix}{i}_{suffix}'
        if variable_name in globals():
            variable_values.append(globals()[variable_name])
    return variable_values

variable_values17 = create_variable_values_list()

# %%
def run_create_over_variables(matches, value, start_identifier):
    for i, match in enumerate(matches):
        prefix = f'm{start_identifier + i}' 
        create_over_variables(match, value, i + 1, prefix)

# %%
for i, var in enumerate(variable_values17, start=1):
    create_over_variables17(var, 20, 1, f'm{i}')

# %%
for i, var in enumerate(variable_values17, start=1):
    create_over_variables17(var, 20, 2, f'm{i}')

# %%
top_scorer_s1=s1_07_08.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s2=s2_09.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s3=s3_09_10.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s4=s4_11.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s5=s5_12.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s6=s6_13.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s7=s7_14.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s8=s8_15.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s9=s9_16.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s10=s10_17.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s11=s11_18.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s12=s12_19.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s13=s13_20_21.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s14=s14_21.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s15=s15_22.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s16=s16_23.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)
top_scorer_s17=s17_24.groupby(by="batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)

# %%
top_scorer_s1
# Out:
#           batter         batting_team  batsman_runs
# 0       SE Marsh      Kings XI Punjab           616
# 1      G Gambhir     Delhi Daredevils           534
# 2  ST Jayasuriya       Mumbai Indians           514
# 3      SR Watson     Rajasthan Royals           472
# 4       GC Smith     Rajasthan Royals           441
# 5   AC Gilchrist      Deccan Chargers           436
# 6      YK Pathan     Rajasthan Royals           435
# 7       SK Raina  Chennai Super Kings           421
# 8       MS Dhoni  Chennai Super Kings           414
# 9       V Sehwag     Delhi Daredevils           406

# %%
top_scorer_s2
# Out:
#            batter           batting_team  batsman_runs
# 0       ML Hayden    Chennai Super Kings           572
# 1    AC Gilchrist        Deccan Chargers           495
# 2  AB de Villiers       Delhi Daredevils           465
# 3        SK Raina    Chennai Super Kings           434
# 4      TM Dilshan       Delhi Daredevils           418
# 5       JP Duminy         Mumbai Indians           372
# 6        HH Gibbs        Deccan Chargers           371
# 7        BJ Hodge  Kolkata Knight Riders           365
# 8    SR Tendulkar         Mumbai Indians           364
# 9       RG Sharma        Deccan Chargers           362

# %%
top_scorer_s3
# Out:
#              batter                 batting_team  batsman_runs
# 0      SR Tendulkar               Mumbai Indians           618
# 1         JH Kallis  Royal Challengers Bangalore           572
# 2          SK Raina          Chennai Super Kings           528
# 3        SC Ganguly        Kolkata Knight Riders           493
# 4           M Vijay          Chennai Super Kings           458
# 5  DPMD Jayawardene              Kings XI Punjab           445
# 6         A Symonds              Deccan Chargers           429
# 7         SS Tiwary               Mumbai Indians           419
# 8         RG Sharma              Deccan Chargers           404
# 9           NV Ojha             Rajasthan Royals           377

# %%
top_scorer_s4
# Out:
#          batter                 batting_team  batsman_runs
# 0      CH Gayle  Royal Challengers Bangalore           608
# 1       V Kohli  Royal Challengers Bangalore           557
# 2  SR Tendulkar               Mumbai Indians           553
# 3      SE Marsh              Kings XI Punjab           504
# 4    MEK Hussey          Chennai Super Kings           492
# 5   PC Valthaty              Kings XI Punjab           463
# 6      SK Raina          Chennai Super Kings           438
# 7       M Vijay          Chennai Super Kings           434
# 8      V Sehwag             Delhi Daredevils           424
# 9     JH Kallis        Kolkata Knight Riders           424

# %%
top_scorer_s5
# Out:
#           batter                 batting_team  batsman_runs
# 0       CH Gayle  Royal Challengers Bangalore           733
# 1      G Gambhir        Kolkata Knight Riders           590
# 2       S Dhawan              Deccan Chargers           569
# 3      AM Rahane             Rajasthan Royals           560
# 4       V Sehwag             Delhi Daredevils           495
# 5       CL White              Deccan Chargers           479
# 6       R Dravid             Rajasthan Royals           462
# 7       SK Raina          Chennai Super Kings           441
# 8      RG Sharma               Mumbai Indians           433
# 9  Mandeep Singh              Kings XI Punjab           432

# %%
top_scorer_s6
# Out:
#        batter                 batting_team  batsman_runs
# 0  MEK Hussey          Chennai Super Kings           733
# 1    CH Gayle  Royal Challengers Bangalore           720
# 2     V Kohli  Royal Challengers Bangalore           639
# 3    SK Raina          Chennai Super Kings           548
# 4   SR Watson             Rajasthan Royals           543
# 5   RG Sharma               Mumbai Indians           538
# 6  KD Karthik               Mumbai Indians           510
# 7   AM Rahane             Rajasthan Royals           488
# 8    R Dravid             Rajasthan Royals           471
# 9    MS Dhoni          Chennai Super Kings           461

# %%
top_scorer_s7
# Out:
#         batter           batting_team  batsman_runs
# 0   RV Uthappa  Kolkata Knight Riders           660
# 1     DR Smith    Chennai Super Kings           566
# 2   GJ Maxwell        Kings XI Punjab           552
# 3    DA Warner    Sunrisers Hyderabad           528
# 4     SK Raina    Chennai Super Kings           523
# 5     V Sehwag        Kings XI Punjab           455
# 6    DA Miller        Kings XI Punjab           446
# 7    JP Duminy       Delhi Daredevils           410
# 8    MK Pandey  Kolkata Knight Riders           409
# 9  BB McCullum    Chennai Super Kings           405

# %%
top_scorer_s8
# Out:
#            batter                 batting_team  batsman_runs
# 0       DA Warner          Sunrisers Hyderabad           562
# 1       AM Rahane             Rajasthan Royals           540
# 2     LMP Simmons               Mumbai Indians           540
# 3  AB de Villiers  Royal Challengers Bangalore           513
# 4         V Kohli  Royal Challengers Bangalore           505
# 5        CH Gayle  Royal Challengers Bangalore           491
# 6       RG Sharma               Mumbai Indians           482
# 7         SS Iyer             Delhi Daredevils           439
# 8     BB McCullum          Chennai Super Kings           436
# 9      KA Pollard               Mumbai Indians           419

# %%
top_scorer_s9
# Out:
#            batter                 batting_team  batsman_runs
# 0         V Kohli  Royal Challengers Bangalore           973
# 1       DA Warner          Sunrisers Hyderabad           848
# 2  AB de Villiers  Royal Challengers Bangalore           687
# 3        S Dhawan          Sunrisers Hyderabad           501
# 4       G Gambhir        Kolkata Knight Riders           501
# 5       RG Sharma               Mumbai Indians           489
# 6       AM Rahane      Rising Pune Supergiants           480
# 7         M Vijay              Kings XI Punjab           453
# 8       Q de Kock             Delhi Daredevils           445
# 9        SK Raina                Gujarat Lions           399

# %%
top_scorer_s10
# Out:
#         batter            batting_team  batsman_runs
# 0    DA Warner     Sunrisers Hyderabad           641
# 1    G Gambhir   Kolkata Knight Riders           498
# 2     S Dhawan     Sunrisers Hyderabad           479
# 3    SPD Smith  Rising Pune Supergiant           472
# 4     SK Raina           Gujarat Lions           442
# 5      HM Amla         Kings XI Punjab           420
# 6    MK Pandey   Kolkata Knight Riders           396
# 7     PA Patel          Mumbai Indians           395
# 8   KA Pollard          Mumbai Indians           395
# 9  RA Tripathi  Rising Pune Supergiant           391

# %%
top_scorer_s11
# Out:
#           batter                 batting_team  batsman_runs
# 0  KS Williamson          Sunrisers Hyderabad           735
# 1        RR Pant             Delhi Daredevils           684
# 2       KL Rahul              Kings XI Punjab           659
# 3      AT Rayudu          Chennai Super Kings           602
# 4      SR Watson          Chennai Super Kings           555
# 5     JC Buttler             Rajasthan Royals           548
# 6        V Kohli  Royal Challengers Bangalore           530
# 7       SA Yadav               Mumbai Indians           512
# 8     KD Karthik        Kolkata Knight Riders           498
# 9       S Dhawan          Sunrisers Hyderabad           497

# %%
top_scorer_s12
# Out:
#         batter                 batting_team  batsman_runs
# 0    DA Warner          Sunrisers Hyderabad           692
# 1     KL Rahul              Kings XI Punjab           593
# 2    Q de Kock               Mumbai Indians           529
# 3     S Dhawan               Delhi Capitals           521
# 4   AD Russell        Kolkata Knight Riders           514
# 5      RR Pant               Delhi Capitals           494
# 6     CH Gayle              Kings XI Punjab           490
# 7      SS Iyer               Delhi Capitals           467
# 8      V Kohli  Royal Challengers Bangalore           464
# 9  JM Bairstow          Sunrisers Hyderabad           445

# %%
top_scorer_s13
# Out:
#            batter                 batting_team  batsman_runs
# 0        KL Rahul              Kings XI Punjab           676
# 1        S Dhawan               Delhi Capitals           618
# 2       DA Warner          Sunrisers Hyderabad           548
# 3         SS Iyer               Delhi Capitals           519
# 4    Ishan Kishan               Mumbai Indians           516
# 5       Q de Kock               Mumbai Indians           506
# 6        SA Yadav               Mumbai Indians           480
# 7      D Padikkal  Royal Challengers Bangalore           473
# 8         V Kohli  Royal Challengers Bangalore           471
# 9  AB de Villiers  Royal Challengers Bangalore           460

# %%
top_scorer_s14
# Out:
#          batter                 batting_team  batsman_runs
# 0    RD Gaikwad          Chennai Super Kings           635
# 1  F du Plessis          Chennai Super Kings           633
# 2      KL Rahul                 Punjab Kings           626
# 3      S Dhawan               Delhi Capitals           587
# 4    GJ Maxwell  Royal Challengers Bangalore           513
# 5     SV Samson             Rajasthan Royals           484
# 6       PP Shaw               Delhi Capitals           479
# 7  Shubman Gill        Kolkata Knight Riders           478
# 8    MA Agarwal                 Punjab Kings           441
# 9       RR Pant               Delhi Capitals           424

# %%
top_scorer_s15
# Out:
#          batter                 batting_team  batsman_runs
# 0    JC Buttler             Rajasthan Royals           863
# 1      KL Rahul         Lucknow Super Giants           616
# 2     Q de Kock         Lucknow Super Giants           508
# 3     HH Pandya               Gujarat Titans           487
# 4  Shubman Gill               Gujarat Titans           483
# 5     DA Miller               Gujarat Titans           481
# 6  F du Plessis  Royal Challengers Bangalore           468
# 7      S Dhawan                 Punjab Kings           460
# 8     SV Samson             Rajasthan Royals           458
# 9      DJ Hooda         Lucknow Super Giants           451

# %%
top_scorer_s16
# Out:
#          batter                 batting_team  batsman_runs
# 0  Shubman Gill               Gujarat Titans           890
# 1  F du Plessis  Royal Challengers Bangalore           730
# 2     DP Conway          Chennai Super Kings           672
# 3       V Kohli  Royal Challengers Bangalore           639
# 4   YBK Jaiswal             Rajasthan Royals           625
# 5      SA Yadav               Mumbai Indians           605
# 6    RD Gaikwad          Chennai Super Kings           590
# 7     DA Warner               Delhi Capitals           516
# 8      RK Singh        Kolkata Knight Riders           474
# 9  Ishan Kishan               Mumbai Indians           454

# %%
top_scorer_s17
# Out:
#             batter                 batting_team  batsman_runs
# 0          V Kohli  Royal Challengers Bengaluru           741
# 1       RD Gaikwad          Chennai Super Kings           583
# 2          R Parag             Rajasthan Royals           573
# 3          TM Head          Sunrisers Hyderabad           567
# 4        SV Samson             Rajasthan Royals           531
# 5  B Sai Sudharsan               Gujarat Titans           527
# 6         KL Rahul         Lucknow Super Giants           520
# 7         N Pooran         Lucknow Super Giants           499
# 8        SP Narine        Kolkata Knight Riders           488
# 9  Abhishek Sharma          Sunrisers Hyderabad           484

# %%
top_10_batsman_alltime=alldata.groupby("batter")[["batting_team","batsman_runs"]] .agg({"batting_team": "first", "batsman_runs": "sum"}).sort_values(by="batsman_runs",ascending=False).reset_index().head(10)

# %%
top_10_batsman_alltime
# Out:
#            batter                 batting_team  batsman_runs
# 0         V Kohli  Royal Challengers Bangalore          8014
# 1        S Dhawan             Delhi Daredevils          6769
# 2       RG Sharma              Deccan Chargers          6630
# 3       DA Warner             Delhi Daredevils          6567
# 4        SK Raina          Chennai Super Kings          5536
# 5        MS Dhoni          Chennai Super Kings          5243
# 6  AB de Villiers             Delhi Daredevils          5181
# 7        CH Gayle        Kolkata Knight Riders          4997
# 8      RV Uthappa               Mumbai Indians          4954
# 9      KD Karthik             Delhi Daredevils          4843

# %%
values_to_exclude = ["run out"]

# %%
filtered_data = alldata[~alldata["dismissal_kind"].isin(values_to_exclude)]

# %%
top_10_bowlers_alltime = (filtered_data.groupby("bowler")[["bowling_team", "is_wicket"]].agg({"bowling_team": "first", "is_wicket": "sum"}).sort_values(by="is_wicket", ascending=False).reset_index().head(10))

# %%
top_10_bowlers_alltime
# Out:
#        bowler           bowling_team  is_wicket
# 0   YS Chahal         Mumbai Indians        205
# 1   PP Chawla        Kings XI Punjab        192
# 2    DJ Bravo         Mumbai Indians        183
# 3    R Ashwin    Chennai Super Kings        181
# 4     B Kumar          Pune Warriors        181
# 5   SP Narine  Kolkata Knight Riders        180
# 6    A Mishra       Delhi Daredevils        174
# 7  SL Malinga         Mumbai Indians        170
# 8   JJ Bumrah         Mumbai Indians        168
# 9   RA Jadeja       Rajasthan Royals        160

# %%
season1_runs=s1_07_08["total_runs"].sum()
season2_runs=s2_09["total_runs"].sum()
season3_runs=s3_09_10["total_runs"].sum()
season4_runs=s4_11["total_runs"].sum()
season5_runs=s5_12["total_runs"].sum()
season6_runs=s6_13["total_runs"].sum()
season7_runs=s7_14["total_runs"].sum()
season8_runs=s8_15["total_runs"].sum()
season9_runs=s9_16["total_runs"].sum()
season10_runs=s10_17["total_runs"].sum()
season11_runs=s11_18["total_runs"].sum()
season12_runs=s12_19["total_runs"].sum()
season13_runs=s13_20_21["total_runs"].sum()
season14_runs=s14_21["total_runs"].sum()
season15_runs=s15_22["total_runs"].sum()
season16_runs=s16_23["total_runs"].sum()
season17_runs=s17_24["total_runs"].sum()

# %%
seasons_runs={
    "season":["season1","season2","season3","season4","season5","season6","season7","season8","season9","season10","season11","season12","season13","season14","season15","season16","season17"],
    "total_runs":[season1_runs, season2_runs, season3_runs, season4_runs, season5_runs, season6_runs, season7_runs, season8_runs, season9_runs, season10_runs, season11_runs, season12_runs, season13_runs, season14_runs, season15_runs, season16_runs ,season17_runs]
}

# %%
season_runs_df = pd.DataFrame(seasons_runs)

# %%
season_runs_df
# Out:
#       season  total_runs
# 0    season1       17937
# 1    season2       16353
# 2    season3       18883
# 3    season4       21154
# 4    season5       22453
# 5    season6       22602
# 6    season7       18931
# 7    season8       18353
# 8    season9       18862
# 9   season10       18786
# 10  season11       19901
# 11  season12       19434
# 12  season13       19416
# 13  season14       18637
# 14  season15       24395
# 15  season16       25688
# 16  season17       25971

# %%
season1_wickets=s1_07_08["is_wicket"].sum()
season2_wickets=s2_09["is_wicket"].sum()
season3_wickets=s3_09_10["is_wicket"].sum()
season4_wickets=s4_11["is_wicket"].sum()
season5_wickets=s5_12["is_wicket"].sum()
season6_wickets=s6_13["is_wicket"].sum()
season7_wickets=s7_14["is_wicket"].sum()
season8_wickets=s8_15["is_wicket"].sum()
season9_wickets=s9_16["is_wicket"].sum()
season10_wickets=s10_17["is_wicket"].sum()
season11_wickets=s11_18["is_wicket"].sum()
season12_wickets=s12_19["is_wicket"].sum()
season13_wickets=s13_20_21["is_wicket"].sum()
season14_wickets=s14_21["is_wicket"].sum()
season15_wickets=s15_22["is_wicket"].sum()
season16_wickets=s16_23["is_wicket"].sum()
season17_wickets=s17_24["is_wicket"].sum()

# %%
seasons_wickets={
    "season":["season1", "season2", "season3", "season4", "season5", "season6","season7","season8","season9","season10","season11","season12","season13","season14","season15","season16","season17"],
    "wickets":[season1_wickets,season2_wickets,season3_wickets,season4_wickets,season5_wickets,season6_wickets,season7_wickets,season8_wickets,season9_wickets,season10_wickets,season11_wickets,season12_wickets,season13_wickets,season14_wickets,season15_wickets,season16_wickets,season17_wickets]
}

# %%
season_wickets_df=pd.DataFrame(seasons_wickets)

# %%
season_wickets_df
# Out:
#       season  wickets
# 0    season1      690
# 1    season2      698
# 2    season3      725
# 3    season4      813
# 4    season5      858
# 5    season6      912
# 6    season7      674
# 7    season8      691
# 8    season9      666
# 9   season10      711
# 10  season11      722
# 11  season12      685
# 12  season13      677
# 13  season14      717
# 14  season15      912
# 15  season16      916
# 16  season17      883

# %%
season1_winners=s1_07_08.groupby("id")["winner"].first().reset_index()
season1_winners=season1_winners["winner"].value_counts().reset_index()

season2_winners=s2_09.groupby("id")["winner"].first().reset_index()
season2_winners=season2_winners["winner"].value_counts().reset_index()

season3_winners=s3_09_10.groupby("id")["winner"].first().reset_index()
season3_winners=season3_winners["winner"].value_counts().reset_index()

season4_winners=s4_11.groupby("id")["winner"].first().reset_index()
season4_winners=season4_winners["winner"].value_counts().reset_index()

season5_winners=s5_12.groupby("id")["winner"].first().reset_index()
season5_winners=season5_winners["winner"].value_counts().reset_index()

season6_winners=s6_13.groupby("id")["winner"].first().reset_index()
season6_winners=season6_winners["winner"].value_counts().reset_index()

season7_winners=s7_14.groupby("id")["winner"].first().reset_index()
season7_winners=season7_winners["winner"].value_counts().reset_index()

season8_winners=s8_15.groupby("id")["winner"].first().reset_index()
season8_winners=season8_winners["winner"].value_counts().reset_index()

season9_winners=s9_16.groupby("id")["winner"].first().reset_index()
season9_winners=season9_winners["winner"].value_counts().reset_index()

season10_winners=s10_17.groupby("id")["winner"].first().reset_index()
season10_winners=season10_winners["winner"].value_counts().reset_index()

season11_winners=s11_18.groupby("id")["winner"].first().reset_index()
season11_winners=season11_winners["winner"].value_counts().reset_index()

season12_winners=s12_19.groupby("id")["winner"].first().reset_index()
season12_winners=season12_winners["winner"].value_counts().reset_index()

season13_winners=s13_20_21.groupby("id")["winner"].first().reset_index()
season13_winners=season13_winners["winner"].value_counts().reset_index()

season14_winners=s14_21.groupby("id")["winner"].first().reset_index()
season14_winners=season14_winners["winner"].value_counts().reset_index()

season15_winners=s15_22.groupby("id")["winner"].first().reset_index()
season15_winners=season15_winners["winner"].value_counts().reset_index()

season16_winners=s16_23.groupby("id")["winner"].first().reset_index()
season16_winners=season16_winners["winner"].value_counts().reset_index()

season17_winners=s17_24.groupby("id")["winner"].first().reset_index()
season17_winners=season17_winners["winner"].value_counts().reset_index()

# %%
season1_winners
# Out:
#                         winner  count
# 0             Rajasthan Royals     13
# 1              Kings XI Punjab     10
# 2          Chennai Super Kings      9
# 3             Delhi Daredevils      7
# 4               Mumbai Indians      7
# 5        Kolkata Knight Riders      6
# 6  Royal Challengers Bangalore      4
# 7              Deccan Chargers      2

# %%
season2_winners
# Out:
#                         winner  count
# 0             Delhi Daredevils     10
# 1  Royal Challengers Bangalore      9
# 2              Deccan Chargers      9
# 3          Chennai Super Kings      8
# 4              Kings XI Punjab      7
# 5             Rajasthan Royals      6
# 6               Mumbai Indians      5
# 7        Kolkata Knight Riders      3

# %%
season3_winners
# Out:
#                         winner  count
# 0               Mumbai Indians     11
# 1          Chennai Super Kings      9
# 2              Deccan Chargers      8
# 3  Royal Challengers Bangalore      8
# 4        Kolkata Knight Riders      7
# 5             Delhi Daredevils      7
# 6             Rajasthan Royals      6
# 7              Kings XI Punjab      4

# %%
season4_winners
# Out:
#                         winner  count
# 0          Chennai Super Kings     11
# 1  Royal Challengers Bangalore     10
# 2               Mumbai Indians     10
# 3        Kolkata Knight Riders      8
# 4              Kings XI Punjab      7
# 5             Rajasthan Royals      6
# 6              Deccan Chargers      6
# 7         Kochi Tuskers Kerala      6
# 8                Pune Warriors      4
# 9             Delhi Daredevils      4

# %%
season5_winners
# Out:
#                         winner  count
# 0        Kolkata Knight Riders     12
# 1             Delhi Daredevils     11
# 2               Mumbai Indians     10
# 3          Chennai Super Kings     10
# 4  Royal Challengers Bangalore      8
# 5              Kings XI Punjab      8
# 6             Rajasthan Royals      7
# 7                Pune Warriors      4
# 8              Deccan Chargers      4

# %%
season6_winners
# Out:
#                         winner  count
# 0               Mumbai Indians     13
# 1          Chennai Super Kings     12
# 2             Rajasthan Royals     11
# 3          Sunrisers Hyderabad     10
# 4  Royal Challengers Bangalore      9
# 5              Kings XI Punjab      8
# 6        Kolkata Knight Riders      6
# 7                Pune Warriors      4
# 8             Delhi Daredevils      3

# %%
season7_winners
# Out:
#                         winner  count
# 0              Kings XI Punjab     12
# 1        Kolkata Knight Riders     11
# 2          Chennai Super Kings     10
# 3             Rajasthan Royals      7
# 4               Mumbai Indians      7
# 5          Sunrisers Hyderabad      6
# 6  Royal Challengers Bangalore      5
# 7             Delhi Daredevils      2

# %%
season8_winners
# Out:
#                         winner  count
# 0          Chennai Super Kings     10
# 1               Mumbai Indians     10
# 2  Royal Challengers Bangalore      8
# 3        Kolkata Knight Riders      7
# 4             Rajasthan Royals      7
# 5          Sunrisers Hyderabad      7
# 6             Delhi Daredevils      5
# 7              Kings XI Punjab      3

# %%
season9_winners
# Out:
#                         winner  count
# 0          Sunrisers Hyderabad     11
# 1                Gujarat Lions      9
# 2  Royal Challengers Bangalore      9
# 3        Kolkata Knight Riders      8
# 4               Mumbai Indians      7
# 5             Delhi Daredevils      7
# 6      Rising Pune Supergiants      5
# 7              Kings XI Punjab      4

# %%
season10_winners
# Out:
#                         winner  count
# 0               Mumbai Indians     12
# 1       Rising Pune Supergiant     10
# 2        Kolkata Knight Riders      9
# 3          Sunrisers Hyderabad      8
# 4              Kings XI Punjab      7
# 5             Delhi Daredevils      6
# 6                Gujarat Lions      4
# 7  Royal Challengers Bangalore      3

# %%
season11_winners
# Out:
#                         winner  count
# 0          Chennai Super Kings     11
# 1          Sunrisers Hyderabad     10
# 2        Kolkata Knight Riders      9
# 3             Rajasthan Royals      7
# 4              Kings XI Punjab      6
# 5  Royal Challengers Bangalore      6
# 6               Mumbai Indians      6
# 7             Delhi Daredevils      5

# %%
season12_winners
# Out:
#                         winner  count
# 0               Mumbai Indians     11
# 1          Chennai Super Kings     10
# 2               Delhi Capitals     10
# 3        Kolkata Knight Riders      6
# 4              Kings XI Punjab      6
# 5          Sunrisers Hyderabad      6
# 6             Rajasthan Royals      5
# 7  Royal Challengers Bangalore      5

# %%
season13_winners
# Out:
#                         winner  count
# 0               Mumbai Indians     11
# 1               Delhi Capitals      9
# 2          Sunrisers Hyderabad      8
# 3  Royal Challengers Bangalore      7
# 4        Kolkata Knight Riders      7
# 5          Chennai Super Kings      6
# 6             Rajasthan Royals      6
# 7              Kings XI Punjab      6

# %%
season14_winners
# Out:
#                         winner  count
# 0          Chennai Super Kings     11
# 1               Delhi Capitals     10
# 2  Royal Challengers Bangalore      9
# 3        Kolkata Knight Riders      9
# 4               Mumbai Indians      7
# 5                 Punjab Kings      6
# 6             Rajasthan Royals      5
# 7          Sunrisers Hyderabad      3

# %%
season15_winners
# Out:
#                         winner  count
# 0               Gujarat Titans     12
# 1             Rajasthan Royals     10
# 2  Royal Challengers Bangalore      9
# 3         Lucknow Super Giants      9
# 4               Delhi Capitals      7
# 5                 Punjab Kings      7
# 6        Kolkata Knight Riders      6
# 7          Sunrisers Hyderabad      6
# 8          Chennai Super Kings      4
# 9               Mumbai Indians      4

# %%
season16_winners
# Out:
#                         winner  count
# 0               Gujarat Titans     11
# 1          Chennai Super Kings     10
# 2               Mumbai Indians      9
# 3         Lucknow Super Giants      8
# 4             Rajasthan Royals      7
# 5  Royal Challengers Bangalore      7
# 6                 Punjab Kings      6
# 7        Kolkata Knight Riders      6
# 8               Delhi Capitals      5
# 9          Sunrisers Hyderabad      4

# %%
season17_winners
# Out:
#                         winner  count
# 0        Kolkata Knight Riders     11
# 1             Rajasthan Royals      9
# 2          Sunrisers Hyderabad      9
# 3          Chennai Super Kings      7
# 4  Royal Challengers Bengaluru      7
# 5         Lucknow Super Giants      7
# 6               Delhi Capitals      7
# 7                 Punjab Kings      5
# 8               Gujarat Titans      5
# 9               Mumbai Indians      4

# %%
h=s1_07_08.groupby("id")["winner"].first().reset_index()

# %%
h
# Out:
#         id                       winner
# 0   335982        Kolkata Knight Riders
# 1   335983          Chennai Super Kings
# 2   335984             Delhi Daredevils
# 3   335985  Royal Challengers Bangalore
# 4   335986        Kolkata Knight Riders
# 5   335987             Rajasthan Royals
# 6   335988             Delhi Daredevils
# 7   335989          Chennai Super Kings
# 8   335990             Rajasthan Royals
# 9   335991              Kings XI Punjab
# 10  335992             Rajasthan Royals
# 11  335993          Chennai Super Kings
# 12  335994              Deccan Chargers
# 13  335995              Kings XI Punjab
# 14  335996          Chennai Super Kings
# 15  335997               Mumbai Indians
# 16  335998             Delhi Daredevils
# 17  335999              Kings XI Punjab
# 18  336000             Rajasthan Royals
# 19  336001             Delhi Daredevils
# 20  336002  Royal Challengers Bangalore
# 21  336003              Kings XI Punjab
# ...

# %%
s1_07_08
# Out:
#            id   season       city        date match_type player_of_match  \
# 0      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...       ...      ...        ...         ...        ...             ...
# 13484  336040  2007/08     Mumbai  2008-06-01      Final       YK Pathan
# 13485  336040  2007/08     Mumbai  2008-06-01      Final       YK Pathan
# 13486  336040  2007/08     Mumbai  2008-06-01      Final       YK Pathan
# 13487  336040  2007/08     Mumbai  2008-06-01      Final       YK Pathan
# 13488  336040  2007/08     Mumbai  2008-06-01      Final       YK Pathan
#
#                             venue                        team1  \
# ...

# %%
plt.figure(figsize=(12, 6))
sn.barplot(data=top_10_batsman_alltime, x='batter', y='batsman_runs',hue='batter', palette='viridis', legend=False)
plt.gca().set_facecolor('lightblue')
plt.title('top 10')
plt.xlabel('batsman')
plt.ylabel('runs')
plt.show()

# %%
top_10_batsman_alltime
# Out:
#            batter                 batting_team  batsman_runs
# 0         V Kohli  Royal Challengers Bangalore          8014
# 1        S Dhawan             Delhi Daredevils          6769
# 2       RG Sharma              Deccan Chargers          6630
# 3       DA Warner             Delhi Daredevils          6567
# 4        SK Raina          Chennai Super Kings          5536
# 5        MS Dhoni          Chennai Super Kings          5243
# 6  AB de Villiers             Delhi Daredevils          5181
# 7        CH Gayle        Kolkata Knight Riders          4997
# 8      RV Uthappa               Mumbai Indians          4954
# 9      KD Karthik             Delhi Daredevils          4843
