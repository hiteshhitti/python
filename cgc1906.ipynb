# %%
class greet:
    def greet1(self):
        print('good morning')
    def greet2(self):
        print('good evening')

# %%
hello=greet()

# %%
hello.greet1()
# Out:
# good morning

# %%
hello.greet2()
# Out:
# good evening

# %%
class cal:
    def ssum(self, num1, num2):
        self.num1=num1
        self.num2=num2
        print(self.num1+self.num2)
    def subt(self, num1, num2):
        self.num1=num1
        self.num2=num2
        print(self.num1-self.num2)

# %%
hey=cal()

# %%
hey.ssum(3,5)
# Out:
# 8

# %%
hey.subt(8,4)
# Out:
# 4

# %%
class cal2:
    def __init__(self,name, age):
        self.name=name
        self.age=age
        print('object created')
    def details(self):
        print(f'Name of the person is {self.name} and age is {self.age}')

# %%
p1=cal2('Aman', 24)
# Out:
# object created

# %%
p1.details()
# Out:
# Name of the person is Aman and age is 24

# %%
import math

# %%
class circle:
    def __init__(self,radius):
        self.radius=radius
        print('object created')
    def area(self):
        print(math.pi*(self.radius**2))
    def perimeter(self):
        print(2*math.pi*self.radius)

# %%
c1=circle(25)
# Out:
# object created

# %%
c1.area()
# Out:
# 1963.4954084936207

# %%
c1.perimeter()
# Out:
# 157.07963267948966

# %%
class bank:
    def __init__(self, name, balance):
        self.name=name
        self.balance=balance
        print(f'account for Mr.{self.name} is opened')
    def deposit(self, amount):
        self.balance+=amount
    def withdraw(self, amount):
        if amount<=self.balance:
            self.balance-=amount
        else:
            print('insufficient funds')
    def show(self):
        print(f'name: {self.name}\nBalance: {self.balance}')

# %%
acc=bank('Amit', 5000)
# Out:
# account for Mr.Amit is opened

# %%
abhi=bank('abhi', 5000)
# Out:
# account for Mr.abhi is opened

# %%
abhi.show()
# Out:
# name: abhi
# Balance: 5000

# %%
abhi.deposit(900)

# %%
acc.deposit(500)

# %%
abhi.show()
# Out:
# name: abhi
# Balance: 5900

# %%
acc.show()
# Out:
# name: Amit
# Balance: 5500

# %%
class school:
    school='CGC'
    def __init__(self, name, roll):
        self.name=name
        self.roll=roll

# %%
student1=school('Suraj', 76)
student2=school('Rajan', 35)

# %%
student1.school
# Out:
# 'CGC'

# %%
student2.school
# Out:
# 'CGC'

# %%
student1.name
# Out:
# 'Suraj'

# %%
student2.name
# Out:
# 'Rajan'

# %%
del student1.name

# %%
student1.name='Rohit'

# %%
student1.name
# Out:
# 'Rohit'

# %%
student1.roll*student2.roll
# Out:
# 2660

# %%
class student:
    def __init__(self, name, value):
        self.name=name
        self.value=value
        print('object created')
    def add(self,num):
        self.num=num
        self.value+=num
    def __str__(self):
        return f'name of the student is {self.name} and value is {self.value}'

# %%
student12=student('amit',45)
# Out:
# object created

# %%
print(student12)
# Out:
# name of the student is amit and value is 45

# %%
student12.add(33)

# %%
print(student12)
# Out:
# name of the student is amit and value is 78

# %%
a=student12

# %%
print(a)
# Out:
# name of the student is amit and value is 78

# %%
# inheritence

# %%
class A:
    def dog(self):
        print('bark')

# %%
class B(A):
    def cat(self):
        print('meow')

# %%
animal=B()

# %%
animal.cat()
# Out:
# meow

# %%
animal.dog()
# Out:
# bark

# %%
class C(B):
    def snake(self):
        print('hisss')

# %%
class D(A):
    def dog(self):
        print('pug')

# %%
class sounds:
    def blast(self):
        print('kaboom')
    def dog(self):
        print('bow')
    def cat(self):
        print('meow')

# %%
class sounds2(sounds):
    def blast(self):
        print('boom')
    def snake(self):
        print('hiss')
    def blastnew(self):
        super().blast()

# %%
abc=sounds2()

# %%
abc.blastnew()
# Out:
# kaboom

# %%
class ABC:
    def __init__(self):
        self.x=10
        self.y=20

# %%
class xyz(ABC):
    def __init__(self):
        super().__init__()
        self.x=15

# %%
qw=xyz()

# %%
qw.y
# Out:
# 20

# %%
qw.x
# Out:
# 15

# %%
class checkvow:
    def __init__(self, word):
        self.word=word
    def checkvowel(self):
        self.word=self.word.lower()
        vowels='aeiou'
        vc=cc=0
        for ch in self.word:
            if ch.isalpha():
                if ch in vowels:
                    vc+=1
                else:
                    cc+=1
        print('vowels are: ', vc)
        print('consonants are: ',cc)
    def checkvowel2(self):
        self.word=self.word.lower()
        vowels='aeiou'
        vc=cc=0
        for ch in self.word:
            if ch.isalpha():
                if ch in vowels:
                    print(ch)
    def countwor(self):
        count=0
        for i in self.word:
            count+=1
        print(count)

# %%
word1=checkvow('himalya')

# %%
word1.checkvowel()
# Out:
# vowels are:  3
# consonants are:  4

# %%
word1.checkvowel2()
# Out:
# i
# a
# a

# %%
word1.countwor()
# Out:
# 7

# %%
from abc import ABC, abstractmethod

# %%
class shape(ABC):
    @abstractmethod
    def area(self):
        pass
    @abstractmethod
    def peri(self):
        pass
    @abstractmethod
    def vol(self):
        pass

# %%
class circular(shape):
    def __init__(self, r):
        self.r=r
    def area(self):
        print(math.pi*(r**2))
    def peri(self):
        print(2*math.pi*r)
    def vol(self):
        print(math.pi*(r**3))
    def show(self):
        print('to check')

# %%
circle23=circular(34)
