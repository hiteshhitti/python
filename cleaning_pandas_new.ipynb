# %%
import pandas as pd

# %%
df=pd.read_csv('large_messy_dataset_option2.csv')

# %%
df
# Out:
#      CustomerID     Name   Age         Salary        City               Email  \
# 0             0    riya    NaN         116530         NaN    riya48@gmail.com
# 1           139   rohit   32.0            NaN         NaN   rohit42@gmail.com
# 2             2   Anjali   NaN         -10000  Chandigarh  anjali18@gmail.com
# 3             3    riya   -3.0         -10000     Kolkata     riya8@gmail.com
# 4            58    Karan   NaN         112349       Delhi   karan43@gmail.com
# ..          ...      ...   ...            ...         ...                 ...
# 295          11    karan  -3.0  Not Available      Mumbai   karan29@gmail.com
# 296          88   anjali  54.0          39808       Delhi  anjali43@gmail.com
# 297         121   Simran   0.0         -10000     Kolkata  simran16@gmail.com
# 298         298    Rohit   NaN         -10000      Mumbai   rohit11@gmail.com
# 299         299     Aman   NaN            NaN     Kolkata    aman17@gmail.com
#
#        JoiningDate
# ...

# %%
df.rename(columns={'CustomerID':'Student_ID'}, inplace=True)

# %%
df
# Out:
#      Student_ID     Name   Age         Salary        City               Email  \
# 0             0    riya    NaN         116530         NaN    riya48@gmail.com
# 1           139   rohit   32.0            NaN         NaN   rohit42@gmail.com
# 2             2   Anjali   NaN         -10000  Chandigarh  anjali18@gmail.com
# 3             3    riya   -3.0         -10000     Kolkata     riya8@gmail.com
# 4            58    Karan   NaN         112349       Delhi   karan43@gmail.com
# ..          ...      ...   ...            ...         ...                 ...
# 295          11    karan  -3.0  Not Available      Mumbai   karan29@gmail.com
# 296          88   anjali  54.0          39808       Delhi  anjali43@gmail.com
# 297         121   Simran   0.0         -10000     Kolkata  simran16@gmail.com
# 298         298    Rohit   NaN         -10000      Mumbai   rohit11@gmail.com
# 299         299     Aman   NaN            NaN     Kolkata    aman17@gmail.com
#
#        JoiningDate
# ...

# %%
df.rename(columns={
    'Student_ID':'S_ID',
    'Age':'Student_Age'
}, inplace=True)

# %%
df
# Out:
#      S_ID     Name  Student_Age         Salary        City  \
# 0       0    riya           NaN         116530         NaN
# 1     139   rohit          32.0            NaN         NaN
# 2       2   Anjali          NaN         -10000  Chandigarh
# 3       3    riya          -3.0         -10000     Kolkata
# 4      58    Karan          NaN         112349       Delhi
# ..    ...      ...          ...            ...         ...
# 295    11    karan         -3.0  Not Available      Mumbai
# 296    88   anjali         54.0          39808       Delhi
# 297   121   Simran          0.0         -10000     Kolkata
# 298   298    Rohit          NaN         -10000      Mumbai
# 299   299     Aman          NaN            NaN     Kolkata
#
#                   Email    JoiningDate
# 0      riya48@gmail.com     2023/04/20
# 1     rohit42@gmail.com     15/02/2023
# 2    anjali18@gmail.com  March 10 2023
# 3       riya8@gmail.com     2023/04/20
# 4     karan43@gmail.com     2023-01-15
# ...

# %%
df.columns.str.lower()
# Out:
# Index(['s_id', 'name', 'student_age', 'salary', 'city', 'email',
#        'joiningdate'],
#       dtype='object')

# %%
df.columns.str.replace(' ','_')
# Out:
# Index(['S_ID', 'Name', 'Student_Age', 'Salary', 'City', 'Email',
#        'JoiningDate'],
#       dtype='object')

# %%
df['Student_Age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['Student_Age'].astype(int)
#
# File D:\python\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File D:\python\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
# ...

# %%
pd.to_numeric(df['Student_Age'], errors='coerce')
# Out:
# 0       NaN
# 1      32.0
# 2       NaN
# 3      -3.0
# 4       NaN
#        ...
# 295    -3.0
# 296    54.0
# 297     0.0
# 298     NaN
# 299     NaN
# Name: Student_Age, Length: 300, dtype: float64

# %%
pd.to_datetime(df['JoiningDate'], format="%d/%m/%Y")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 pd.to_datetime(df['JoiningDate'], format="%d/%m/%Y")
#
# File D:\python\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File D:\python\Lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# --> 247     cache_dates = convert_listlike(unique_dates, format)
#     248     # GH#45319
# ...

# %%
df
# Out:
#      S_ID     Name  Student_Age         Salary        City  \
# 0       0    riya           NaN         116530         NaN
# 1     139   rohit          32.0            NaN         NaN
# 2       2   Anjali          NaN         -10000  Chandigarh
# 3       3    riya          -3.0         -10000     Kolkata
# 4      58    Karan          NaN         112349       Delhi
# ..    ...      ...          ...            ...         ...
# 295    11    karan         -3.0  Not Available      Mumbai
# 296    88   anjali         54.0          39808       Delhi
# 297   121   Simran          0.0         -10000     Kolkata
# 298   298    Rohit          NaN         -10000      Mumbai
# 299   299     Aman          NaN            NaN     Kolkata
#
#                   Email    JoiningDate
# 0      riya48@gmail.com     2023/04/20
# 1     rohit42@gmail.com     15/02/2023
# 2    anjali18@gmail.com  March 10 2023
# 3       riya8@gmail.com     2023/04/20
# 4     karan43@gmail.com     2023-01-15
# ...

# %%
pd.to_datetime(
    df['JoiningDate'],
    format='mixed',
    dayfirst=True,
    errors='coerce'
)
# Out:
# 0     2023-04-20
# 1     2023-02-15
# 2     2023-03-10
# 3     2023-04-20
# 4     2023-01-15
#          ...
# 295          NaT
# 296   2023-04-20
# 297   2023-01-15
# 298   2023-02-15
# 299   2023-01-15
# Name: JoiningDate, Length: 300, dtype: datetime64[ns]
