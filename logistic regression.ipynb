# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X = data[['BMI', 'BloodPressure', 'Age']]
y = data['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6493506493506493
#
# Confusion Matrix:
#  [[122  29]
#  [ 52  28]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.81      0.75       151
#            1       0.49      0.35      0.41        80
#
#     accuracy                           0.65       231
#    macro avg       0.60      0.58      0.58       231
# weighted avg       0.63      0.65      0.63       231

# %%
accuracy=model.score(X_test, y_test)

# %%
bmi=float(input('BMI'))
BP=int(input('bp'))
age=int(input('age'))
user_data=np.array([[bmi, BP, age]])
# Out:
# BMI 23
# bp 32
# age 22

# %%
prediction=model.predict(user_data)
# Out:
# D:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print(prediction)
# Out:
# [0]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))
sns.boxplot(data=data[['BMI', 'BloodPressure', 'Age']])
plt.title("Boxplot for BMI, BloodPressure and Age (After Outlier Removal)")
plt.xlabel("Features")
plt.ylabel("Values")
plt.show()

# %%
columns_to_check = ['BMI', 'BloodPressure', 'Age']

for column in columns_to_check:
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data[['BMI', 'BloodPressure', 'Age']])
plt.title("Boxplot for BMI, BloodPressure and Age (After Outlier Removal)")
plt.xlabel("Features")
plt.ylabel("Values")
plt.show()

# %%
X = data[['BMI','BloodPressure', 'Age']]
y = data['Outcome']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy=model.score(X_test, y_test)

# %%
bmi=float(input('BMI'))
BP=int(input('bp'))
age=int(input('age'))
user_data=np.array([[bmi,BP, age]])
prediction=model.predict(user_data)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(prediction)
# Out:
# BMI 34
# bp 120
# age 22
# Accuracy: 0.7320574162679426
# [0]
# D:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
data.shape
# Out:
# (696, 9)
