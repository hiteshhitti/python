# %%
import pandas as pd

# %%
df=pd.read_csv('large_messy_dataset_option2.csv')

# %%
df.head(3)
# Out:
#    CustomerID     Name   Age  Salary        City               Email  \
# 0           0    riya    NaN  116530         NaN    riya48@gmail.com
# 1         139   rohit   32.0     NaN         NaN   rohit42@gmail.com
# 2           2   Anjali   NaN  -10000  Chandigarh  anjali18@gmail.com
#
#      JoiningDate
# 0     2023/04/20
# 1     15/02/2023
# 2  March 10 2023

# %%
df.tail()
# Out:
#      CustomerID    Name   Age         Salary     City               Email  \
# 295          11   karan  -3.0  Not Available   Mumbai   karan29@gmail.com
# 296          88  anjali  54.0          39808    Delhi  anjali43@gmail.com
# 297         121  Simran   0.0         -10000  Kolkata  simran16@gmail.com
# 298         298   Rohit   NaN         -10000   Mumbai   rohit11@gmail.com
# 299         299    Aman   NaN            NaN  Kolkata    aman17@gmail.com
#
#     JoiningDate
# 295         NaN
# 296  2023/04/20
# 297  2023-01-15
# 298  15/02/2023
# 299  2023-01-15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   300 non-null    int64
#  1   Name         300 non-null    object
#  2   Age          225 non-null    float64
#  3   Salary       227 non-null    object
#  4   City         251 non-null    object
#  5   Email        300 non-null    object
#  6   JoiningDate  234 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 16.5+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age
# count  300.000000  225.000000
# mean   114.746667   10.746667
# std     80.658385   19.774009
# min      0.000000   -3.000000
# 25%     45.750000   -3.000000
# 50%    101.000000    0.000000
# 75%    156.250000   25.000000
# max    299.000000   59.000000

# %%
df.isnull().sum()
# Out:
# CustomerID      0
# Name            0
# Age            75
# Salary         73
# City           49
# Email           0
# JoiningDate    66
# dtype: int64

# %%
df.dropna()
# Out:
#      CustomerID      Name   Age         Salary        City  \
# 3             3     riya   -3.0         -10000     Kolkata
# 5             5    Simran  -3.0  Not Available  Chandigarh
# 7             7    Priya   -3.0         -10000   Bangalore
# 8            35       raj   0.0         -10000  Chandigarh
# 9           119     Aman    0.0          98172   Bangalore
# ..          ...       ...   ...            ...         ...
# 286          46    Karan   29.0         -10000     Kolkata
# 289          25    Anjali   0.0  Not Available     Kolkata
# 290          18   simran   -3.0  Not Available  Chandigarh
# 296          88    anjali  54.0          39808       Delhi
# 297         121    Simran   0.0         -10000     Kolkata
#
#                   Email    JoiningDate
# 3       riya8@gmail.com     2023/04/20
# 5    simran14@gmail.com     2023/04/20
# 7     priya42@gmail.com  March 10 2023
# 8       raj15@gmail.com     2023-01-15
# 9      aman25@gmail.com     2023/04/20
# ...

# %%
pd.to_numeric(df['Salary'], errors='coerce')
# Out:
# 0      116530.0
# 1           NaN
# 2      -10000.0
# 3      -10000.0
# 4      112349.0
#          ...
# 295         NaN
# 296     39808.0
# 297    -10000.0
# 298    -10000.0
# 299         NaN
# Name: Salary, Length: 300, dtype: float64

# %%
df['Salary']=pd.to_numeric(df['Salary'], errors='coerce')

# %%
df
# Out:
#      CustomerID     Name   Age    Salary        City               Email  \
# 0             0    riya    NaN  116530.0         NaN    riya48@gmail.com
# 1           139   rohit   32.0       NaN         NaN   rohit42@gmail.com
# 2             2   Anjali   NaN  -10000.0  Chandigarh  anjali18@gmail.com
# 3             3    riya   -3.0  -10000.0     Kolkata     riya8@gmail.com
# 4            58    Karan   NaN  112349.0       Delhi   karan43@gmail.com
# ..          ...      ...   ...       ...         ...                 ...
# 295          11    karan  -3.0       NaN      Mumbai   karan29@gmail.com
# 296          88   anjali  54.0   39808.0       Delhi  anjali43@gmail.com
# 297         121   Simran   0.0  -10000.0     Kolkata  simran16@gmail.com
# 298         298    Rohit   NaN  -10000.0      Mumbai   rohit11@gmail.com
# 299         299     Aman   NaN       NaN     Kolkata    aman17@gmail.com
#
#        JoiningDate
# 0       2023/04/20
# 1       15/02/2023
# 2    March 10 2023
# ...

# %%
df['Salary']=df['Salary'].abs()

# %%
df.describe()
# Out:
#        CustomerID         Age         Salary
# count  300.000000  225.000000     152.000000
# mean   114.746667   10.746667   38273.750000
# std     80.658385   19.774009   36837.249772
# min      0.000000   -3.000000   10000.000000
# 25%     45.750000   -3.000000   10000.000000
# 50%    101.000000    0.000000   10000.000000
# 75%    156.250000   25.000000   66370.000000
# max    299.000000   59.000000  119613.000000

# %%
df['Salary'].isnull().sum()
# Out:
# 148

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].mean())

# %%
df['Salary'].mean()
# Out:
# 38273.75

# %%
df['Salary'].median()
# Out:
# 38273.75

# %%
df['Salary'].mode()
# Out:
# 0    38273.75
# Name: Salary, dtype: float64

# %%
df.describe()
# Out:
#        CustomerID         Age         Salary
# count  300.000000  225.000000     300.000000
# mean   114.746667   10.746667   38273.750000
# std     80.658385   19.774009   26178.217897
# min      0.000000   -3.000000   10000.000000
# 25%     45.750000   -3.000000   10000.000000
# 50%    101.000000    0.000000   38273.750000
# 75%    156.250000   25.000000   38273.750000
# max    299.000000   59.000000  119613.000000

# %%
df[(df['Salary']>=10000) & (df['Salary']<=25000)]
# Out:
#      CustomerID      Name   Age   Salary        City               Email  \
# 2             2    Anjali   NaN  10000.0  Chandigarh  anjali18@gmail.com
# 3             3     riya   -3.0  10000.0     Kolkata     riya8@gmail.com
# 7             7    Priya   -3.0  10000.0   Bangalore   priya42@gmail.com
# 8            35       raj   0.0  10000.0  Chandigarh     raj15@gmail.com
# 13           13    simran  23.0  10000.0       Delhi  simran49@gmail.com
# ..          ...       ...   ...      ...         ...                 ...
# 286          46    Karan   29.0  10000.0     Kolkata    karan3@gmail.com
# 291         291    rohit   -3.0  10000.0         NaN    rohit2@gmail.com
# 294         101   anjali   -3.0  10000.0       Delhi  anjali20@gmail.com
# 297         121    Simran   0.0  10000.0     Kolkata  simran16@gmail.com
# 298         298     Rohit   NaN  10000.0      Mumbai   rohit11@gmail.com
#
#        JoiningDate
# 2    March 10 2023
# 3       2023/04/20
# 7    March 10 2023
# ...

# %%
df[df['Salary']==10000]
# Out:
#      CustomerID      Name   Age   Salary        City               Email  \
# 2             2    Anjali   NaN  10000.0  Chandigarh  anjali18@gmail.com
# 3             3     riya   -3.0  10000.0     Kolkata     riya8@gmail.com
# 7             7    Priya   -3.0  10000.0   Bangalore   priya42@gmail.com
# 8            35       raj   0.0  10000.0  Chandigarh     raj15@gmail.com
# 13           13    simran  23.0  10000.0       Delhi  simran49@gmail.com
# ..          ...       ...   ...      ...         ...                 ...
# 286          46    Karan   29.0  10000.0     Kolkata    karan3@gmail.com
# 291         291    rohit   -3.0  10000.0         NaN    rohit2@gmail.com
# 294         101   anjali   -3.0  10000.0       Delhi  anjali20@gmail.com
# 297         121    Simran   0.0  10000.0     Kolkata  simran16@gmail.com
# 298         298     Rohit   NaN  10000.0      Mumbai   rohit11@gmail.com
#
#        JoiningDate
# 2    March 10 2023
# 3       2023/04/20
# 7    March 10 2023
# ...

# %%
modes=df['Salary'].mode()

# %%
modes
# Out:
# 0    38273.75
# Name: Salary, dtype: float64

# %%
print(modes)
# Out:
# 0    38273.75
# Name: Salary, dtype: float64

# %%
df['Salary'].value_counts()[lambda x: x>1]
# Out:
# Salary
# 38273.75    148
# 10000.00     86
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   300 non-null    int64
#  1   Name         300 non-null    object
#  2   Age          225 non-null    float64
#  3   Salary       300 non-null    float64
#  4   City         251 non-null    object
#  5   Email        300 non-null    object
#  6   JoiningDate  234 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 16.5+ KB

# %%
df['Age']=df['Age'].abs()

# %%
df['Age'].mean()
# Out:
# 12.826666666666666

# %%
df.loc[df['Age']>20, 'Age'].mean()
# Out:
# 39.621212121212125

# %%
age_mean=df.loc[df['Age']>20, 'Age'].mean()

# %%
age_mean
# Out:
# 39.621212121212125

# %%
df.loc[(df['Age']>=0) & (df['Age']<=19), 'Age']=age_mean

# %%
df['Age']=df['Age'].fillna(39.62)

# %%
df['Age'].mean()
# Out:
# 39.620909090909095

# %%
df['Age']=df['Age'].round()

# %%
df['Age']=df['Age'].astype(int)

# %%
df
# Out:
#      CustomerID     Name  Age     Salary        City               Email  \
# 0             0    riya    40  116530.00         NaN    riya48@gmail.com
# 1           139   rohit    32   38273.75         NaN   rohit42@gmail.com
# 2             2   Anjali   40   10000.00  Chandigarh  anjali18@gmail.com
# 3             3    riya    40   10000.00     Kolkata     riya8@gmail.com
# 4            58    Karan   40  112349.00       Delhi   karan43@gmail.com
# ..          ...      ...  ...        ...         ...                 ...
# 295          11    karan   40   38273.75      Mumbai   karan29@gmail.com
# 296          88   anjali   54   39808.00       Delhi  anjali43@gmail.com
# 297         121   Simran   40   10000.00     Kolkata  simran16@gmail.com
# 298         298    Rohit   40   10000.00      Mumbai   rohit11@gmail.com
# 299         299     Aman   40   38273.75     Kolkata    aman17@gmail.com
#
#        JoiningDate
# 0       2023/04/20
# 1       15/02/2023
# 2    March 10 2023
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   300 non-null    int64
#  1   Name         300 non-null    object
#  2   Age          300 non-null    int32
#  3   Salary       300 non-null    float64
#  4   City         251 non-null    object
#  5   Email        300 non-null    object
#  6   JoiningDate  234 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(4)
# memory usage: 15.4+ KB

# %%
df['City'].isnull().sum()
# Out:
# 49

# %%
city_null=df[df['City'].isnull()]

# %%
city_null
# Out:
#      CustomerID      Name  Age     Salary City               Email  \
# 0             0     riya    40  116530.00  NaN    riya48@gmail.com
# 1           139    rohit    32   38273.75  NaN   rohit42@gmail.com
# 6             6      Raj    40   38273.75  NaN     raj21@gmail.com
# 11           11      Aman   40   86542.00  NaN    aman20@gmail.com
# 14          102   Anjali    40   38273.75  NaN  anjali20@gmail.com
# 18           18     Priya   21   10000.00  NaN   priya22@gmail.com
# 26           34     Karan   59   38273.75  NaN    karan7@gmail.com
# 33           33     Karan   40   10000.00  NaN   karan35@gmail.com
# 36          129     rohit   40  106951.00  NaN   rohit20@gmail.com
# 37           44    Priya    40   10000.00  NaN   priya48@gmail.com
# 39           39      riya   40   38273.75  NaN    riya20@gmail.com
# 40           49      aman   57   10000.00  NaN    aman37@gmail.com
# 43          133    Anjali   40   38273.75  NaN  anjali18@gmail.com
# ...

# %%
df.dropna(subset=['City'], inplace=True)

# %%
df[df['Email']=='anjali18@gmail.com']
# Out:
#      CustomerID    Name  Age    Salary        City               Email  \
# 2             2  Anjali   40  10000.00  Chandigarh  anjali18@gmail.com
# 55           55  Anjali   40  38273.75       Delhi  anjali18@gmail.com
# 276         276  anjali   40  38273.75  Chandigarh  anjali18@gmail.com
#
#        JoiningDate
# 2    March 10 2023
# 55             NaN
# 276     2023-01-15

# %%
city_null.insert(0, 'sr_no', range(1, len(city_null)+1))

# %%
city_null
# Out:
#      sr_no  CustomerID      Name  Age     Salary City  sr_no1  \
# 0        1           0     riya    40  116530.00  NaN       1
# 1        2         139    rohit    32   38273.75  NaN       2
# 6        3           6      Raj    40   38273.75  NaN       3
# 11       4          11      Aman   40   86542.00  NaN       4
# 14       5         102   Anjali    40   38273.75  NaN       5
# 18       6          18     Priya   21   10000.00  NaN       6
# 26       7          34     Karan   59   38273.75  NaN       7
# 33       8          33     Karan   40   10000.00  NaN       8
# 36       9         129     rohit   40  106951.00  NaN       9
# 37      10          44    Priya    40   10000.00  NaN      10
# 39      11          39      riya   40   38273.75  NaN      11
# 40      12          49      aman   57   10000.00  NaN      12
# 43      13         133    Anjali   40   38273.75  NaN      13
# 47      14          47   Simran    49   38273.75  NaN      14
# ...

# %%
city_null.loc[city_null['sr_no']==1, 'City']='Delhi'

# %%
def enter_city():
    city=input('enter city name')
    sr_no=int(input('serial'))
    city_null.loc[city_null['sr_no']==sr_no, 'City']=city

# %%
value=city_null.loc[city_null['sr_no']==4, 'City']

# %%
value=city_null.loc[city_null['sr_no']==5, 'City']

# %%
pd.isna(value)
# Out:
# 14    True
# Name: City, dtype: bool

# %%
city_null.reset_index(inplace=True)

# %%
mask=(city_null['sr_no'] == 55) & (city_null['City'].isna())

# %%
mask
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# dtype: bool

# %%
mask.any()
# Out:
# False

# %%
def enter_city():
    city = input("Enter city name: ")
    sr_no = int(input("Enter serial number: "))
    
    # Condition: sr_no match AND City is null
    mask = (city_null['sr_no'] == sr_no) & (city_null['City'].isna())
    
    if mask.any():
        city_null.loc[mask, 'City'] = city
        print("City updated successfully ")
    else:
        print("City already exists or invalid serial number ")

# %%
enter_city()
# Out:
# Enter city name:  landran
# Enter serial number:  1
# City already exists or invalid serial number ❌
