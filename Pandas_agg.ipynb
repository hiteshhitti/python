# %%
import pandas as pd

# %%
df=pd.read_csv('US_honey_dataset_updated.csv')

# %%
df['state'].unique()
# Out:
# array(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'NewJersey', 'NewMexico', 'NewYork',
#        'NorthCarolina', 'NorthDakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'SouthCarolina', 'SouthDakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'WestVirginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df['state'].nunique()
# Out:
# 44

# %%
for i in df['state'].unique():
    print(i)
# Out:
# Alabama
# Arizona
# Arkansas
# California
# Colorado
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# NewJersey
# NewMexico
# NewYork
# NorthCarolina
# NorthDakota
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# SouthCarolina
# SouthDakota
# Tennessee
# Texas
# Utah
# Vermont
# Virginia
# Washington
# WestVirginia
# Wisconsin
# Wyoming

# %%
df.groupby('state')['production'].sum()
# Out:
# state
# Alabama           14467000
# Arizona           38844000
# Arkansas          51846000
# California       423876000
# Colorado          32660000
# Florida          280934000
# Georgia           57426000
# Hawaii            15420000
# Idaho             87188000
# Illinois           9864000
# Indiana            9686000
# Iowa              48607000
# Kansas            14138000
# Kentucky           3224000
# Louisiana         60568000
# Maine              4762000
# Maryland           1975000
# Michigan         101063000
# Minnesota        176581000
# Mississippi       21235000
# Missouri          17904000
# Montana          197173000
# Nebraska          63655000
# Nevada             7399000
# NewJersey          6913000
# NewMexico         10082000
# NewYork           78444000
# NorthCarolina      8909000
# NorthDakota      513742000
# Ohio              22485000
# Oklahoma           2055000
# Oregon            43789000
# Pennsylvania      21370000
# SouthCarolina      2823000
# ...

# %%
df.groupby('state').sum()
# Out:
#                Unnamed: 0  colonies_number  yield_per_colony  production  \
# state
# Alabama             14784           288000              1615    14467000
# Arizona             14811           854000              1490    38844000
# Arkansas            14838           908000              1886    51846000
# California          14865         10135000              1426   423876000
# Colorado            14892           799000              1520    32660000
# Florida             14919          5528000              1956   280934000
# Georgia             14946          1917000              1354    57426000
# Hawaii              14973           296000              2802    15420000
# Idaho               15000          2705000              1121    87188000
# Illinois            15027           236000              1562     9864000
# Indiana             15054           213000              1605     9686000
# Iowa                15081           962000              1659    48607000
# ...

# %%
df.groupby('state')['production'].agg(['sum','mean','max'])
# Out:
#                      sum        mean       max
# state
# Alabama         14467000   535814.81   1248000
# Arizona         38844000  1438666.67   4108000
# Arkansas        51846000  1920222.22   5655000
# California     423876000 15699111.11  39060000
# Colorado        32660000  1209629.63   2700000
# Florida        280934000 10404962.96  25200000
# Georgia         57426000  2126888.89   5100000
# Hawaii          15420000   571111.11   1314000
# Idaho           87188000  3229185.19   7680000
# Illinois         9864000   365333.33    814000
# Indiana          9686000   358740.74    828000
# Iowa            48607000  1800259.26   3900000
# Kansas          14138000   523629.63   1207000
# Kentucky         3224000   124000.00    280000
# Louisiana       60568000  2243259.26   5472000
# Maine            4762000   176370.37    495000
# Maryland         1975000   219444.44    308000
# Michigan       101063000  3743074.07   8924000
# Minnesota      176581000  6540037.04  13530000
# ...

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df.groupby(['state','year'])['production'].sum()
# Out:
# state          year
# Alabama        1995      928000
#                1996     1024000
#                1997      924000
#                1998     1136000
#                1999     1156000
#                2000     1248000
#                2001     1022000
#                2002     1032000
#                2003     1066000
#                2004     1044000
#                2005      858000
#                2006      792000
#                2007      616000
#                2008      594000
#                2009      441000
#                2010       73000
#                2011       63000
#                2012       65000
#                2013       55000
#                2014       26000
#                2015       13000
#                2016       33000
#                2017       22000
#                2018       14000
#                2019       44000
#                2020       66000
#                2021      112000
# Arizona        1995     4108000
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.groupby('state')['production'].sum().reset_index()
# Out:
#             state  production
# 0         Alabama    14467000
# 1         Arizona    38844000
# 2        Arkansas    51846000
# 3      California   423876000
# 4        Colorado    32660000
# 5         Florida   280934000
# 6         Georgia    57426000
# 7          Hawaii    15420000
# 8           Idaho    87188000
# 9        Illinois     9864000
# 10        Indiana     9686000
# 11           Iowa    48607000
# 12         Kansas    14138000
# 13       Kentucky     3224000
# 14      Louisiana    60568000
# 15          Maine     4762000
# 16       Maryland     1975000
# 17       Michigan   101063000
# 18      Minnesota   176581000
# 19    Mississippi    21235000
# 20       Missouri    17904000
# 21        Montana   197173000
# 22       Nebraska    63655000
# 23         Nevada     7399000
# 24      NewJersey     6913000
# 25      NewMexico    10082000
# 26        NewYork    78444000
# 27  NorthCarolina     8909000
# 28    NorthDakota   513742000
# 29           Ohio    22485000
# ...

# %%
df.groupby('state')['value_of_production'].sum().sort_values(ascending=False)
# Out:
# state
# NorthDakota      1186219000
# California        653982000
# SouthDakota       619095000
# Florida           509670000
# Montana           406563000
# Minnesota         310462000
# Texas             284720000
# Michigan          217841000
# NewYork           177921000
# Wisconsin         176442000
# Georgia           145945000
# Idaho             139536000
# Louisiana         129601000
# Washington        119823000
# Nebraska          106998000
# Oregon            102109000
# Iowa               87563000
# Wyoming            87502000
# Arkansas           73781000
# Colorado           63844000
# Arizona            59772000
# Ohio               59637000
# Mississippi        59265000
# Pennsylvania       55153000
# Hawaii             49888000
# Utah               40157000
# NorthCarolina      38645000
# Illinois           36782000
# Missouri           32372000
# Alabama            28668000
# NewJersey          28201000
# Kansas             27970000
# Tennessee          27276000
# ...

# %%
df.groupby('state').agg({
'production':'sum',
'average_price':'mean',
'value_of_production':'sum'
})
# Out:
#                production  average_price  value_of_production
# state
# Alabama          14467000     150.281852             28668000
# Arizona          38844000     110.324815             59772000
# Arkansas         51846000     106.312963             73781000
# California      423876000     109.409630            653982000
# Colorado         32660000     118.539259             63844000
# Florida         280934000     109.908148            509670000
# Georgia          57426000     120.765926            145945000
# Hawaii           15420000     137.745556             49888000
# Idaho            87188000     106.285556            139536000
# Illinois          9864000     216.386296             36782000
# Indiana           9686000     154.931852             24658000
# Iowa             48607000     123.768519             87563000
# Kansas           14138000     147.312593             27970000
# Kentucky          3224000     201.940385             15427000
# ...

# %%
df.groupby('state').agg(
Total_Production=('production','sum'),
Avg_Price=('average_price','mean'),
Total_Revenue=('value_of_production','sum')
)
# Out:
#                Total_Production  Avg_Price  Total_Revenue
# state
# Alabama                14467000     150.28       28668000
# Arizona                38844000     110.32       59772000
# Arkansas               51846000     106.31       73781000
# California            423876000     109.41      653982000
# Colorado               32660000     118.54       63844000
# Florida               280934000     109.91      509670000
# Georgia                57426000     120.77      145945000
# Hawaii                 15420000     137.75       49888000
# Idaho                  87188000     106.29      139536000
# Illinois                9864000     216.39       36782000
# Indiana                 9686000     154.93       24658000
# Iowa                   48607000     123.77       87563000
# Kansas                 14138000     147.31       27970000
# Kentucky                3224000     201.94       15427000
# Louisiana              60568000     103.07      129601000
# ...

# %%
df.groupby('state')['production'].sum().nlargest(5)
# Out:
# state
# NorthDakota    513742000
# California     423876000
# SouthDakota    355726000
# Florida        280934000
# Montana        197173000
# Name: production, dtype: int64

# %%
df.groupby('state')['production'].sum().sort_values(ascending=False)
# Out:
# state
# NorthDakota      513742000
# California       423876000
# SouthDakota      355726000
# Florida          280934000
# Montana          197173000
# Minnesota        176581000
# Texas            129441000
# Michigan         101063000
# Wisconsin         99909000
# Idaho             87188000
# NewYork           78444000
# Nebraska          63655000
# Louisiana         60568000
# Georgia           57426000
# Washington        53238000
# Arkansas          51846000
# Iowa              48607000
# Wyoming           43921000
# Oregon            43789000
# Arizona           38844000
# Colorado          32660000
# Ohio              22485000
# Pennsylvania      21370000
# Mississippi       21235000
# Utah              20369000
# Missouri          17904000
# Hawaii            15420000
# Alabama           14467000
# Kansas            14138000
# NewMexico         10082000
# Illinois           9864000
# Indiana            9686000
# NorthCarolina      8909000
# Nevada             7399000
# ...

# %%
df.groupby(['state','year'])['production'].sum()
# Out:
# state          year
# Alabama        1995      928000
#                1996     1024000
#                1997      924000
#                1998     1136000
#                1999     1156000
#                2000     1248000
#                2001     1022000
#                2002     1032000
#                2003     1066000
#                2004     1044000
#                2005      858000
#                2006      792000
#                2007      616000
#                2008      594000
#                2009      441000
#                2010       73000
#                2011       63000
#                2012       65000
#                2013       55000
#                2014       26000
#                2015       13000
#                2016       33000
#                2017       22000
#                2018       14000
#                2019       44000
#                2020       66000
#                2021      112000
# Arizona        1995     4108000
# ...

# %%
df.groupby('state').filter(lambda x: x['production'].sum() > 1000000)
# Out:
#       Unnamed: 0          state  colonies_number  yield_per_colony  \
# 0              0        Alabama            16000                58
# 1              1        Arizona            52000                79
# 2              2       Arkansas            50000                60
# 3              3     California           420000                93
# 4              4       Colorado            45000                60
# 5              5        Florida           230000                86
# 6              6        Georgia            70000                62
# 7              7         Hawaii             8000               129
# 8              8          Idaho           125000                48
# 9              9       Illinois            11000                74
# 10            10        Indiana            12000                63
# 11            11           Iowa            50000                68
# 12            12         Kansas            17000                67
# ...

# %%
df.groupby(['state','year']).agg(
Total_Production=('production','sum'),
Avg_Price=('average_price','mean'),
Revenue=('value_of_production','sum')
).reset_index()
# Out:
#               state  year  Total_Production  Avg_Price   Revenue
# 0           Alabama  1995            928000      62.00    575000
# 1           Alabama  1996           1024000      86.00    881000
# 2           Alabama  1997            924000      81.00    748000
# 3           Alabama  1998           1136000      72.00    818000
# 4           Alabama  1999           1156000      56.00    647000
# 5           Alabama  2000           1248000      59.00    736000
# 6           Alabama  2001           1022000      71.00    726000
# 7           Alabama  2002           1032000     111.00   1146000
# 8           Alabama  2003           1066000     126.00   1343000
# 9           Alabama  2004           1044000     140.00   1462000
# 10          Alabama  2005            858000     128.00   1098000
# 11          Alabama  2006            792000     146.00   1156000
# 12          Alabama  2007            616000     141.00    869000
# ...
