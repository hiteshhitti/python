# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load dataset
df = pd.read_csv("Reviews.csv")
df = df[['Text', 'Score']].dropna()
df = df[df['Score'] != 3]  # Keep only positive(4,5) and negative(1,2)

# Convert to binary sentiment
df['Sentiment'] = df['Score'].apply(lambda x: 1 if x > 3 else 0)

# Split
X_train, X_test, y_train, y_test = train_test_split(df['Text'], df['Sentiment'], test_size=0.2)

# Tokenization
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X_train)

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

X_train_pad = pad_sequences(X_train_seq, maxlen=100)
X_test_pad = pad_sequences(X_test_seq, maxlen=100)

# Build model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=10000, output_dim=16, input_length=100),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# Train
model.fit(X_train_pad, y_train, epochs=15, batch_size=128, validation_split=0.1)

# Evaluate
loss, acc = model.evaluate(X_test_pad, y_test)
print("Test Accuracy:", acc)
# Out:
# D:\python\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling1d             │ ?                           │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 35s 11ms/step - accuracy: 0.8761 - loss: 0.3150 - val_accuracy: 0.9285 - val_loss: 0.1806
# Epoch 2/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 29s 10ms/step - accuracy: 0.9330 - loss: 0.1714 - val_accuracy: 0.9317 - val_loss: 0.1768
# Epoch 3/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 36s 12ms/step - accuracy: 0.9395 - loss: 0.1563 - val_accuracy: 0.9340 - val_loss: 0.1702
# Epoch 4/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 35s 12ms/step - accuracy: 0.9412 - loss: 0.1518 - val_accuracy: 0.9363 - val_loss: 0.1653
# Epoch 5/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 34s 11ms/step - accuracy: 0.9430 - loss: 0.1466 - val_accuracy: 0.9363 - val_loss: 0.1625
# Epoch 6/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 35s 12ms/step - accuracy: 0.9435 - loss: 0.1450 - val_accuracy: 0.9313 - val_loss: 0.1827
# Epoch 7/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 31s 10ms/step - accuracy: 0.9471 - loss: 0.1370 - val_accuracy: 0.9395 - val_loss: 0.1608
# Epoch 8/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 31s 10ms/step - accuracy: 0.9484 - loss: 0.1333 - val_accuracy: 0.9400 - val_loss: 0.1578
# Epoch 9/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 35s 12ms/step - accuracy: 0.9510 - loss: 0.1272 - val_accuracy: 0.9345 - val_loss: 0.1694
# Epoch 10/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 33s 11ms/step - accuracy: 0.9523 - loss: 0.1230 - val_accuracy: 0.9404 - val_loss: 0.1593
# Epoch 11/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9541 - loss: 0.1191 - val_accuracy: 0.9362 - val_loss: 0.1694
# Epoch 12/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9553 - loss: 0.1149 - val_accuracy: 0.9399 - val_loss: 0.1638
# Epoch 13/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9574 - loss: 0.1119 - val_accuracy: 0.9364 - val_loss: 0.1736
# Epoch 14/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9589 - loss: 0.1080 - val_accuracy: 0.9356 - val_loss: 0.1746
# Epoch 15/15
# 2958/2958 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9601 - loss: 0.1052 - val_accuracy: 0.9385 - val_loss: 0.1720
# 3287/3287 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9396 - loss: 0.1668
# Test Accuracy: 0.9385144710540771

# %%
new_review = ["it was nice experience"]

# %%
new_seq = tokenizer.texts_to_sequences(new_review)
new_pad = pad_sequences(new_seq, maxlen=100)

# %%
pred = model.predict(new_pad)
print("Raw Prediction (sigmoid):", pred[0][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# Raw Prediction (sigmoid): 0.8849601

# %%
final_sentiment = "Positive" if pred[0][0] >= 0.5 else "Negative"
print("Predicted Sentiment:", final_sentiment)
# Out:
# Predicted Sentiment: Positive
